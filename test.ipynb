# %% [markdown]
# <a href="https://colab.research.google.com/github/ozasd/project_llm_research/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')  # 修正掛載點

import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks')  # 根據你的實際路徑修改
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/ozasd/project_llm_research.git
# Out:
# fatal: destination path 'project_llm_research' already exists and is not an empty directory.
# /content/project_llm_research

# %%
# !git switch -c utility_fine_tune_demo origin/utility_fine_tune_demo
# !git branch -a
# Out:
# fatal: A branch named 'utility_fine_tune_demo' already exists.
#   main
#   remotes/origin/utility_fine_tune_demo
# * utility_fine_tune_demo
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/main
#   remotes/origin/utility_fine_tune_demo

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys

BASE = '/content/drive/MyDrive/Colab Notebooks'
REPO = 'project_llm_research'
REPO_PATH = f'{BASE}/{REPO}'

# %cd {BASE}
# !pwd

# !test -d {REPO} || git clone https://github.com/ozasd/project_llm_research.git

# %cd {REPO_PATH}

# !git fetch

# !git rev-parse --verify utility_fine_tune_demo \
  || git switch -c utility_fine_tune_demo origin/utility_fine_tune_demo

# !git branch -a

if REPO_PATH not in sys.path:
    sys.path.append(REPO_PATH)
# %cd QLoRA
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks
# /content/drive/MyDrive/Colab Notebooks
# /content/drive/MyDrive/Colab Notebooks/project_llm_research
# 18cf4ca366c6b9f7070a285ed980c186477cc84a
#   main
# * utility_fine_tune_demo
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/main
#   remotes/origin/utility_fine_tune_demo
# /content/drive/MyDrive/Colab Notebooks/project_llm_research/QLoRA

# %%
# %%bash
# wget -q https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# bash Miniconda3-latest-Linux-x86_64.sh -b -p /usr/local/miniconda
# Out:
# PREFIX=/usr/local/miniconda
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local/miniconda

# %%
import os
os.environ['PATH'] = '/usr/local/miniconda/bin:' + os.environ['PATH']

# %%
# !conda --version
# Out:
# conda 25.11.1

# %%
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
# !conda config --add channels conda-forge
# !conda config --set channel_priority flexible
# !conda env create -f environment.yml
# Out:
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r
# Jupyter detected...
# 2 channel Terms of Service accepted
# done
# Channels:
#  - pytorch
#  - nvidia
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.11.1
#     latest version: 26.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ...
# pytorch-2.5.1        | 1.35 GB   | :   0% 0/1 [00:00<?, ?it/s]
# libcublas-12.1.0.26  | 329.0 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
# torchtriton-3.1.0    | 233.5 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
# mkl-2023.1.0         | 171.5 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libcusparse-12.0.2.5 | 163.0 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# ...

# %%
# %%bash
# source /usr/local/miniconda/etc/profile.d/conda.sh
# conda activate llama3zh
# python -V
# python train_zh_lora.py
# Out:
# Python 3.10.19
# {'loss': '1.531', 'grad_norm': '0.7148', 'learning_rate': '0.0001928', 'entropy': '1.769', 'num_tokens': '1.406e+04', 'mean_token_accuracy': '0.6184', 'epoch': '0.04'}
# {'loss': '1.504', 'grad_norm': '0.6562', 'learning_rate': '0.0001848', 'entropy': '1.698', 'num_tokens': '2.726e+04', 'mean_token_accuracy': '0.6212', 'epoch': '0.08'}
# {'loss': '1.451', 'grad_norm': '0.6406', 'learning_rate': '0.0001768', 'entropy': '1.629', 'num_tokens': '4.194e+04', 'mean_token_accuracy': '0.6389', 'epoch': '0.12'}
# {'loss': '1.429', 'grad_norm': '0.6172', 'learning_rate': '0.0001688', 'entropy': '1.66', 'num_tokens': '5.549e+04', 'mean_token_accuracy': '0.6357', 'epoch': '0.16'}
# {'loss': '1.396', 'grad_norm': '0.7188', 'learning_rate': '0.0001608', 'entropy': '1.605', 'num_tokens': '6.99e+04', 'mean_token_accuracy': '0.6308', 'epoch': '0.2'}
# ...

# %% [markdown]
# Python 3.10.19
# {'loss': '1.531', 'grad_norm': '0.7148', 'learning_rate': '0.0001928', 'entropy': '1.769', 'num_tokens': '1.406e+04', 'mean_token_accuracy': '0.6184', 'epoch': '0.04'}
# {'loss': '1.504', 'grad_norm': '0.6562', 'learning_rate': '0.0001848', 'entropy': '1.698', 'num_tokens': '2.726e+04', 'mean_token_accuracy': '0.6212', 'epoch': '0.08'}
# {'loss': '1.451', 'grad_norm': '0.6406', 'learning_rate': '0.0001768', 'entropy': '1.629', 'num_tokens': '4.194e+04', 'mean_token_accuracy': '0.6389', 'epoch': '0.12'}
# {'loss': '1.429', 'grad_norm': '0.6172', 'learning_rate': '0.0001688', 'entropy': '1.66', 'num_tokens': '5.549e+04', 'mean_token_accuracy': '0.6357', 'epoch': '0.16'}
# {'loss': '1.396', 'grad_norm': '0.7188', 'learning_rate': '0.0001608', 'entropy': '1.605', 'num_tokens': '6.99e+04', 'mean_token_accuracy': '0.6308', 'epoch': '0.2'}
# {'loss': '1.42', 'grad_norm': '0.6758', 'learning_rate': '0.0001528', 'entropy': '1.571', 'num_tokens': '8.672e+04', 'mean_token_accuracy': '0.6385', 'epoch': '0.24'}
# {'loss': '1.341', 'grad_norm': '0.8164', 'learning_rate': '0.0001448', 'entropy': '1.564', 'num_tokens': '1.018e+05', 'mean_token_accuracy': '0.6586', 'epoch': '0.28'}
# {'loss': '1.378', 'grad_norm': '0.9219', 'learning_rate': '0.0001368', 'entropy': '1.579', 'num_tokens': '1.175e+05', 'mean_token_accuracy': '0.6584', 'epoch': '0.32'}
# {'loss': '1.406', 'grad_norm': '0.4766', 'learning_rate': '0.0001288', 'entropy': '1.577', 'num_tokens': '1.342e+05', 'mean_token_accuracy': '0.6454', 'epoch': '0.36'}
# {'loss': '1.295', 'grad_norm': '0.5234', 'learning_rate': '0.0001208', 'entropy': '1.504', 'num_tokens': '1.483e+05', 'mean_token_accuracy': '0.6532', 'epoch': '0.4'}
# {'loss': '1.313', 'grad_norm': '0.5273', 'learning_rate': '0.0001128', 'entropy': '1.498', 'num_tokens': '1.644e+05', 'mean_token_accuracy': '0.6514', 'epoch': '0.44'}
# {'loss': '1.414', 'grad_norm': '0.6055', 'learning_rate': '0.0001048', 'entropy': '1.522', 'num_tokens': '1.772e+05', 'mean_token_accuracy': '0.6454', 'epoch': '0.48'}
# {'loss': '1.31', 'grad_norm': '0.5898', 'learning_rate': '9.68e-05', 'entropy': '1.461', 'num_tokens': '1.938e+05', 'mean_token_accuracy': '0.6639', 'epoch': '0.52'}
# {'loss': '1.371', 'grad_norm': '0.8438', 'learning_rate': '8.88e-05', 'entropy': '1.514', 'num_tokens': '2.069e+05', 'mean_token_accuracy': '0.6601', 'epoch': '0.56'}
# {'loss': '1.325', 'grad_norm': '0.543', 'learning_rate': '8.08e-05', 'entropy': '1.477', 'num_tokens': '2.213e+05', 'mean_token_accuracy': '0.6693', 'epoch': '0.6'}
# {'loss': '1.322', 'grad_norm': '0.5781', 'learning_rate': '7.28e-05', 'entropy': '1.465', 'num_tokens': '2.352e+05', 'mean_token_accuracy': '0.6684', 'epoch': '0.64'}
# {'loss': '1.394', 'grad_norm': '0.7188', 'learning_rate': '6.48e-05', 'entropy': '1.572', 'num_tokens': '2.484e+05', 'mean_token_accuracy': '0.6457', 'epoch': '0.68'}
# {'loss': '1.369', 'grad_norm': '0.5703', 'learning_rate': '5.68e-05', 'entropy': '1.509', 'num_tokens': '2.629e+05', 'mean_token_accuracy': '0.6562', 'epoch': '0.72'}
# {'loss': '1.45', 'grad_norm': '0.582', 'learning_rate': '4.88e-05', 'entropy': '1.564', 'num_tokens': '2.782e+05', 'mean_token_accuracy': '0.6466', 'epoch': '0.76'}
# {'loss': '1.289', 'grad_norm': '0.7148', 'learning_rate': '4.08e-05', 'entropy': '1.477', 'num_tokens': '2.928e+05', 'mean_token_accuracy': '0.659', 'epoch': '0.8'}
# {'loss': '1.314', 'grad_norm': '0.6797', 'learning_rate': '3.28e-05', 'entropy': '1.437', 'num_tokens': '3.079e+05', 'mean_token_accuracy': '0.6685', 'epoch': '0.84'}
# {'loss': '1.337', 'grad_norm': '0.6328', 'learning_rate': '2.48e-05', 'entropy': '1.463', 'num_tokens': '3.211e+05', 'mean_token_accuracy': '0.6718', 'epoch': '0.88'}
# {'loss': '1.352', 'grad_norm': '0.9141', 'learning_rate': '1.68e-05', 'entropy': '1.489', 'num_tokens': '3.369e+05', 'mean_token_accuracy': '0.6546', 'epoch': '0.92'}
# {'loss': '1.32', 'grad_norm': '0.6484', 'learning_rate': '8.8e-06', 'entropy': '1.457', 'num_tokens': '3.514e+05', 'mean_token_accuracy': '0.6698', 'epoch': '0.96'}
# {'loss': '1.362', 'grad_norm': '0.7031', 'learning_rate': '8e-07', 'entropy': '1.54', 'num_tokens': '3.66e+05', 'mean_token_accuracy': '0.665', 'epoch': '1'}
# {'train_runtime': '3574', 'train_samples_per_second': '0.56', 'train_steps_per_second': '0.07', 'train_loss': '1.376', 'epoch': '1'}
# ✅ LoRA saved to ./llama3_zh_lora

# %%
logs = [
{'loss':1.531,'epoch':0.04,'acc':0.6184},
{'loss':1.504,'epoch':0.08,'acc':0.6212},
{'loss':1.451,'epoch':0.12,'acc':0.6389},
{'loss':1.429,'epoch':0.16,'acc':0.6357},
{'loss':1.396,'epoch':0.2,'acc':0.6308},
{'loss':1.42,'epoch':0.24,'acc':0.6385},
{'loss':1.341,'epoch':0.28,'acc':0.6586},
{'loss':1.378,'epoch':0.32,'acc':0.6584},
{'loss':1.406,'epoch':0.36,'acc':0.6454},
{'loss':1.295,'epoch':0.4,'acc':0.6532},
{'loss':1.313,'epoch':0.44,'acc':0.6514},
{'loss':1.414,'epoch':0.48,'acc':0.6454},
{'loss':1.31,'epoch':0.52,'acc':0.6639},
{'loss':1.371,'epoch':0.56,'acc':0.6601},
{'loss':1.325,'epoch':0.6,'acc':0.6693},
{'loss':1.322,'epoch':0.64,'acc':0.6684},
{'loss':1.394,'epoch':0.68,'acc':0.6457},
{'loss':1.369,'epoch':0.72,'acc':0.6562},
{'loss':1.45,'epoch':0.76,'acc':0.6466},
{'loss':1.289,'epoch':0.8,'acc':0.659},
{'loss':1.314,'epoch':0.84,'acc':0.6685},
{'loss':1.337,'epoch':0.88,'acc':0.6718},
{'loss':1.352,'epoch':0.92,'acc':0.6546},
{'loss':1.32,'epoch':0.96,'acc':0.6698},
{'loss':1.362,'epoch':1.0,'acc':0.665},
]
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(logs)

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.plot(df["epoch"], df["loss"], marker="o")
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid()

plt.subplot(1,2,2)
plt.plot(df["epoch"], df["acc"], marker="o", color="green")
plt.title("Mean Token Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid()

plt.show()

# %%
# %%bash
# source /usr/local/miniconda/etc/profile.d/conda.sh
# conda activate llama3zh
# python - <<'PY'
# import torch
# print("cuda_available:", torch.cuda.is_available())
# print("cuda_device_count:", torch.cuda.device_count())
# print("device0:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else None)
# PY
# Out:
# cuda_available: True
# cuda_device_count: 1
# device0: Tesla T4
